# %%
import pandas as pd

# %%
data = pd.read_excel('reto.xlsx', sheet_name='protocolos_produccion')
data.columns()
# Out:
#     Unnamed: 0 Unnamed: 1           Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 0  indice_lote   Estación                Fecha       Hora       Tipo
# 1           32          1  2023-06-19 00:00:00   22:02:05          M
# 2           32          1  2023-06-19 00:00:00   22:06:16          M
# 3           32          1  2023-06-19 00:00:00   22:28:45          M
# 4           32          1  2023-06-19 00:00:00   23:42:56          M
#
#                     Unnamed: 5 Fuerza de compresión  Unnamed: 7 Unnamed: 8  \
# 0  Producción\nAcumulada x1000        PreC VM\n[kN]  CPVM\n[kN]  Srel\n[%]
# 1                           22                 2.16        24.9          6
# 2                           43                 2.76       26.93        6.6
# 3                          157                 2.88       26.26        6.4
# 4                          426                 3.73       29.76        6.6
#
#   Peso  ... Unnamed: 13 Grosor Unnamed: 15 Unnamed: 16 Dureza Unnamed: 18  \
# ...
