# %%
import pandas as pd

# %%
data_og = pd.read_excel('reto.xlsx', sheet_name='protocolos_produccion', skiprows = 1)
data_og.head()
# Out:
#    indice_lote  Estación      Fecha      Hora Tipo  \
# 0           32       1.0 2023-06-19  22:02:05    M
# 1           32       1.0 2023-06-19  22:06:16    M
# 2           32       1.0 2023-06-19  22:28:45    M
# 3           32       1.0 2023-06-19  23:42:56    M
# 4           32       1.0 2023-06-20  00:02:29    M
#
#    Producción\nAcumulada x1000  PreC VM\n[kN]  CPVM\n[kN]  Srel\n[%]   n  ...  \
# 0                           22           2.16       24.90        6.0  10  ...
# 1                           43           2.76       26.93        6.6  10  ...
# 2                          157           2.88       26.26        6.4  10  ...
# 3                          426           3.73       29.76        6.6  10  ...
# 4                          530           3.07       25.94        6.3  10  ...
#
#    Srel\n[%].1  n.1  VM\n[mm]  Srel\n[%].2  n.2  VM\n[kp]  Srel\n[%].3  n.3  \
# 0         1.09   10      5.58         0.60   10      11.9         5.71   10
# 1         1.27   10      5.61         0.56   10      11.8         6.36   10
# 2         1.21   10      5.60         0.55   10      11.3         7.48   10
# 3         0.98   10      5.65         0.44   10      11.9         7.12   10
# 4         0.93   10      5.62         0.47   10      12.0         5.54   10
#
#    VM\n[mm].1  Srel\n[%].4
# 0       21.01         0.05
# 1       21.01         0.06
# 2       21.01         0.02
# 3       21.02         0.11
# 4       21.01         0.02
#
# [5 rows x 23 columns]

# %%
data = data_og.copy()

# %%
data.drop(columns=['Fecha', 'Hora', 'Tipo', 'Estación'], inplace = True)
